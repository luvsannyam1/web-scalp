# %% [markdown]
# Web scalping script for https://portal.laekh.de/wbermaechtigte

# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
type = "2"
radius = "50"
suchfilter = "emptyX%3A%3A%3AXemptyX%3A%3A%3AX0X%3A%3A%3AX72"
last_item_cnt = "0"
url = "https://portal.laekh.de/pages/rest/umkreissuche/search?type="+type+"&standort=&standort_lat=&standort_lon=&radius="+radius+"&suchfilter="+suchfilter+"&last_item_cnt="+last_item_cnt+"&sortfilter=0&sortdir=asc"

payload={}
headers = {
  'Cookie': 'JSESSIONID=D77506604CAE501EB6B7B67E3C324530'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %% [markdown]
# Parsing the json response

# %%
from cgitb import text


json_data = json.loads(response.text)
soup = BeautifulSoup(json_data['adresslist'],'html.parser')
for list in soup.find_all("tr"):
  print(list.find('div',class_='css_bold').text) # ArtzName
  print(list.find('div',class_='wordwrap').text) # Ort
  print(list.find('div',class_='padding_top wordwrap').text) # Address
  print(list.find('div',class_='padding_top css_bold').text) # department
  print(list.find('div',class_='',text = True)) # Duration
  print("=============================================") # Duration
# Out:
# Enayatollah Aazami Gilan
# Kliniken des Main-Taunus-Kreises Bad Soden
# 65812 Bad Soden, Kronberger Str. 36
# Innere Medizin und Nephrologie (WBO 2005)
# <div class="">24 Monate</div>
# =============================================
# Dr. med. Nadine Abahuni
# Praxis Dr. med. Nadine Abahuni
# 60313 Frankfurt, Zeil 29-31
# Allgemeinmedizin (WBO 2020)
# <div class="">18 Monate</div>
# =============================================
# Abraham Abam
# Praxis Abraham Abam
# 63486 Bruchköbel, Innerer Ring 5
# Innere Medizin (WBO 2020)
# <div class="">24 Monate</div>
# =============================================
# Dr. med. Karin Abbel
# GPR Dres. K. Abbel & U. Härtwig
# 63303 Dreieich, Hainer Chaussee 63
# Frauenheilkunde und Geburtshilfe (WBO 2020)
# <div class="">24 Monate</div>
# =============================================
# Dr. med. univ. Mohammed Nasser Abdel-Hadi
# Helios Kliniken Kassel
# 34121 Kassel, Hansteinstr. 29
# Innere Medizin und Kardiologie (WBO 2020)
# <div class="">24 Monate</div>
# =============================================
# Abdelwadoud Abdrabou
# Praxis Abdelwadoud Abdrabou Mohamed
# 34117 Kassel, Kurfürstenstr. 10-12
# Innere Medizin (WBO 2005)
# <div class="">24 Monate</div>
# =============================================
# Malik Abdul Hassan
# GPR Ursula Hahn & Malik Abdul Hassan
# 37213 Witzenhausen, Hinter den Teichhöfen 1
# Innere Medizin (WBO 2005)
# <div class="">24 Monate</div>
# =============================================
# Jamal Abdula
# AGAPLESION Diakoniekliniken Kassel
# 34119 Kassel, Herkulesstr. 34
# Radiologie   (WBO 2020)
# <div class="">12 Monate</div>
# =============================================
# Dr. (CS) Yayu Abebe
# MVZ Panaceum Offenbach
# 63065 Offenbach, Ziegelstr. 33
# Allgemeinmedizin (WBO 2005)
# <div class="">42 Monate</div>
# =============================================
# Dr. med. Johannes Abel
# GPR Dres. Abel & Schulte
# 60325 Frankfurt, Ulmenstr. 43
# Innere Medizin (WBO 2005)
# <div class="">12 Monate</div>
# =============================================
# Docteur en Médecine / Univ.Sousse Naima Abendroth
# Praxis Docteur en Medecine / Univ.Sousse Naima Abendroth
# 63450 Hanau, Salzstr. 13
# Allgemeinmedizin (WBO 2005)
# <div class="">24 Monate</div>
# =============================================
# Dr. med. Leyla Abkai
# Medizinisches Zentrum Eichhof
# 36341 Lauterbach, Eichhofstr. 1
# Innere Medizin (WBO 2020)
# <div class="">48 Monate</div>
# =============================================
# Dr. med. Leyla Abkai
# Medizinisches Zentrum Eichhof
# 36341 Lauterbach, Eichhofstr. 1
# Geriatrie (WBO 2005)
# <div class="">18 Monate</div>
# =============================================
# Dr. med. Osama Abu Hassan
# Praxis Dr. med. Osama Abu Hassan
# 65185 Wiesbaden, Luisenstr. 18
# Schlafmedizin (WBO 2005)
# <div class="">18 Monate</div>
# =============================================
# Dr. med. Osama Abu Hassan
# Praxis Dr. med. Osama Abu Hassan
# 65185 Wiesbaden, Luisenstr. 18
# Innere Medizin (WBO 2005)
# <div class="">24 Monate</div>
# =============================================
# Nicole Abui-Engebrand
# Praxis N. Abui-Engebrand
# 63322 Rödermark, dieburger Str. 23-25
# Kinder- und Jugendpsychiatrie und -psychotherapie (WBO 2020)
# <div class="">12 Monate</div>
# =============================================
# PD Dr. med. Tobias Achenbach
# Lahn-Dill-Kliniken GmbH Klinikum Wetzlar
# 35578 Wetzlar, Forsthausstr. 1
# Radiologie   (WBO 2020)
# <div class="">60 Monate</div>
# =============================================
# Dr. med. Dipl.-Chem. Peter Acker
# GPR Dres. Garth & Kollegen
# 63450 Hanau, Nußallee 7
# Nuklearmedizin (WBO 2005)
# <div class="">60 Monate</div>
# =============================================
# Prof. Dr. med. Till Acker
# UKGM GmbH Standort Gießen
# 35392 Gießen, Arndtstr. 16
# Neuropathologie (WBO 2005)
# <div class="">72 Monate</div>
# =============================================
# Dr. med. Gisbert van Ackeren
# GPR Dr. van Ackeren & Magheti
# 35576 Wetzlar, Bahnhofstr. 19b
# Augenheilkunde (WBO 2005)
# <div class="">24 Monate</div>
# =============================================

# %%
def get_data(last):
  url = "https://portal.laekh.de/pages/rest/umkreissuche/search?type="+type+"&standort=&standort_lat=&standort_lon=&radius="+radius+"&suchfilter="+suchfilter+"&last_item_cnt="+last+"&sortfilter=0&sortdir=asc"
  payload={}
  headers = {
    'Cookie': 'JSESSIONID=D77506604CAE501EB6B7B67E3C324530'
  }
  response = requests.request("GET", url, headers=headers, data=payload)
  json_data = json.loads(response.text)
  soup = BeautifulSoup(json_data['adresslist'],'html.parser')
  print("called")
  iteration = []
  for list in soup.find_all("tr"):
    # print(list.find('div',class_='css_bold').text) # ArtzName
    
    # print(list.find('div',class_='wordwrap').text) # Ort
    # print(list.find('div',class_='padding_top wordwrap').text) # Address
    address= list.find('div',class_='padding_top wordwrap').text.split()
    # print(list.find('div',class_='padding_top css_bold').text) # department
    department = list.find('div',class_='padding_top css_bold').text.split()
    # print(department)
    # print(list.find('div',class_='',text=True)) # Duration
    # print("=============================================") # Duration
    duration = ""
    if hasattr(list.find('div',class_='',text=True),'text') is True:
      duration = list.find('div',class_='').text

    dict = {
      'subject':"",
      'name':list.find('div',class_='css_bold').text,
      'authority_since':"",
      'WBO':department[len(department)-1].replace(')',''),
      'duration' : duration,
      'address':list.find('div',class_='padding_top wordwrap').text,
      'zip':address[0],
      'city':address[1],
      'address_title':'',
      'clinic_type':list.find('div',class_='padding_top css_bold').text,
    }
    print(dict)
    iteration.append(dict)
    
  return iteration

# %%
f = open("collected.json", "a")
collected = []
while int(last_item_cnt) < 5794:
  last_item_cnt =  str(int(last_item_cnt) + 20)
  collected.append(get_data(last_item_cnt))
f.write(json.dumps(collected,indent=2))
f.close()
# Out:
# called
# {'subject': '', 'name': 'PD Dr. med. Sven Ackermann', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '64283 Darmstadt, Grafenstr. 9', 'zip': '64283', 'city': 'Darmstadt,', 'address_title': '', 'clinic_type': 'Gynäkologische Onkologie (WBO 2020)'}
# {'subject': '', 'name': 'PD Dr. med. Sven Ackermann', 'authority_since': '', 'WBO': '2020', 'duration': '60 Monate', 'address': '64283 Darmstadt, Grafenstr. 9', 'zip': '64283', 'city': 'Darmstadt,', 'address_title': '', 'clinic_type': 'Frauenheilkunde und Geburtshilfe (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Klaus Uwe Adam', 'authority_since': '', 'WBO': '2020', 'duration': '12 Monate', 'address': '34127 Kassel, Brandaustr. 10', 'zip': '34127', 'city': 'Kassel,', 'address_title': '', 'clinic_type': 'Psychosomatische Medizin und Psychotherapie (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Michael Adam', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '63589 Linsengericht, Hasselhofstr. 3-5', 'zip': '63589', 'city': 'Linsengericht,', 'address_title': '', 'clinic_type': 'Innere Medizin (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Sabine Adam', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '60486 Frankfurt, Kasseler Str. 1a', 'zip': '60486', 'city': 'Frankfurt,', 'address_title': '', 'clinic_type': 'Allgemeinmedizin (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Karin Ademmer', 'authority_since': '', 'WBO': '2005', 'duration': '24 Monate', 'address': '65719 Hofheim, Lindenstr. 10', 'zip': '65719', 'city': 'Hofheim,', 'address_title': '', 'clinic_type': 'Psychiatrie und Psychotherapie (WBO 2005)'}
# {'subject': '', 'name': 'PD Dr. med. Farzin Adili', 'authority_since': '', 'WBO': '2020', 'duration': '60 Monate', 'address': '64283 Darmstadt, Grafenstr. 9', 'zip': '64283', 'city': 'Darmstadt,', 'address_title': '', 'clinic_type': 'Gefäßchirurgie (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Dominik Adler', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '35390 Gießen, Alicenstr. 4', 'zip': '35390', 'city': 'Gießen,', 'address_title': '', 'clinic_type': 'Frauenheilkunde und Geburtshilfe (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med.
WBO 2005)'}
# {'subject': '', 'name': 'Dr. med. Metin Aksünger', 'authority_since': '', 'WBO': '2005', 'duration': '60 Monate', 'address': '65812 Bad Soden, Kronberger Str. 36', 'zip': '65812', 'city': 'Bad', 'address_title': '', 'clinic_type': 'Urologie (WBO 2005)'}
# {'subject': '', 'name': 'Doctor-medic Anas Al Kadri', 'authority_since': '', 'WBO': '2020', 'duration': '12 Monate', 'address': '63450 Hanau, Nürnberger Str. 20', 'zip': '63450', 'city': 'Hanau,', 'address_title': '', 'clinic_type': 'Haut- und Geschlechtskrankheiten (WBO 2020)'}
# {'subject': '', 'name': 'Ssomer Al-Abesie', 'authority_since': '', 'WBO': '1999', 'duration': '36 Monate', 'address': '61209 Echzell, Weiherstr. 5', 'zip': '61209', 'city': 'Echzell,', 'address_title': '', 'clinic_type': 'Allgemeinmedizin (WBO 1999)'}
# {'subject': '', 'name': 'Dr. med. Nureddin Alamuti', 'authority_since': '', 'WBO': '2020', 'duration': '12 Monate', 'address': '65193 Wiesbaden, Schöne Aussicht 39', 'zip': '65193', 'city': 'Wiesbaden,', 'address_title': '', 'clinic_type': 'Plastische und Ästhetische Chirurgie (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Maik Albert', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '64653 Lorsch, Wilhelm-Leuschner-Str. 10', 'zip': '64653', 'city': 'Lorsch,', 'address_title': '', 'clinic_type': 'Anästhesiologie (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Christiane Albrand-Thielmann', 'authority_since': '', 'WBO': '2020', 'duration': '24 Monate', 'address': '65451 Kelsterbach, Brandenburger Weg 11', 'zip': '65451', 'city': 'Kelsterbach,', 'address_title': '', 'clinic_type': 'Frauenheilkunde und Geburtshilfe (WBO 2020)'}
# {'subject': '', 'name': 'Dr. med. Lars-Hendrik Albrecht', 'authority_since': '', 'WBO': '2005', 'duration': '6 Monate', 'address': '65779 Kelkheim, Marktplatz 5', 'zip': '65779', 'city': 'Kelkheim,', 'address_title': '', 'clinic_type': 'Diabetologie (WBO 2005)'}
# {'subject': '', 'name': 'Dr. med. Lars-Hendrik Albrecht', 'authority_since': '', 'WBO': '2005', 'duration': '24 Monate', 'address': '65779 Kelkheim, Marktplatz 5', 'zip': '65779', 'city': 'Kelkheim,', 'address_title': '', 'clinic_type': 'Innere Medizin (WBO 2005)'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 5
#       3 while int(last_item_cnt) < 5794:
#       4   last_item_cnt =  str(int(last_item_cnt) + 20)
# ----> 5   collected.append(get_data(last_item_cnt))
#       6 f.write(json.dumps(collected,indent=2))
#       7 f.close()
#
# Cell In [10], line 7, in get_data(last)
#       3 payload={}
#       4 headers = {
#       5   'Cookie': 'JSESSIONID=D77506604CAE501EB6B7B67E3C324530'
#       6 }
# ----> 7 response = requests.request("GET", url, headers=headers, data=payload)
#       8 json_data = json.loads(response.text)
#       9 soup = BeautifulSoup(json_data['adresslist'],'html.parser')
#
# File /usr/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /usr/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /usr/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /usr/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /usr/lib/python3.10/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File /usr/lib/python3.10/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /usr/lib/python3.10/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /usr/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File /usr/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File /usr/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:
