# %%
import requests

url = "https://www.laekb.de/www/website/PublicNavigation/arzt/weiterbildung/weiterbildung_befugte/?_dummy=183F60B81B0&phpfile=formular&fname=showResult&wf=wbbsuche&PHPSESSID=e233210f5282d94076cc59f1d251018c&dom=login-laekb.aek-service.de&antzformto=/static/website/custom/php/WBBefugte.php&rserv=www.laekb.de&resultPage=116#extform"

payload={}
files={}
headers = {
  'Content-Type': 'application/x-www-form-urlencoded'
}

response = requests.request("POST", url, headers=headers, data=payload, files=files)

print(response.text)
# Out:
#
# <!DOCTYPE html>
# <html lang="de" class="no-js">
#     <head>
# <meta name="keywords" content="Weiterbildungsbefugnisse, Gebiete, Facharztbezeichnungen, Schwerpunktbezeichnungen, Zusatzbezeichnungen, Weiterbildungsbefugte, Weiterbildungsbefugnis, Befugnis, Weiterbildung">
# <meta name="description" content="Erteilte Weiterbildungsbefugnisse für Gebiete, Facharzt- ,Schwerpunkt- und Zusatzbezeichnungen.">
#
#     <!--test-->
#
#
#
#
#
# 		<meta name="generator" content="BatixCMS" >
#       	<meta http-equiv="content-type" content="text/html; charset=utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" >
#
#         <link rel="canonical" href="https://www.laekb.de/www/website/PublicNavigation/arzt/weiterbildung/weiterbildung_befugte">
#
# <!-- Auslesen der Informationen von Artikeln -->
#
#
# <!-- Auslesen der Informationen von Inhaltsseiten -->
#
# 	<meta property="og:title" content="Weiterbildungsbefugnisse gemäß Weiterbildungsordnung" />
# ...
