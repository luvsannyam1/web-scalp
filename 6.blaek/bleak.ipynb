# %%
import requests

# %%
url = "https://secure.blaek.de/Portal/WBBSuchePortal/WBBSuchePortal/SucheEinfach"

payload={'SuchArt': 'einfach',
'Entfernung': '50',
'Anzahl': '100',
'Search': 'true',
'Befugnis': '',
'Arzt': '',
'wohnort': '',
'paginationIndex': str(152)}
files=[

]
headers = {
  'Content-Type': 'application/x-www-form-urlencoded',
  'Cookie': 'ASP.NET_SessionId=s1nfztxyfh0fff4v2ayd01ih'
}

response = requests.request("POST", url, headers=headers, data=payload, files=files)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width" />
#     <meta http-equiv="X-UA-Compatible" content="IE=9">
#
#     <title>Suche Weiterbildungsstellen - Suchmaske - WBB Suche</title>
#
#     <link href="/Portal/WBBSuchePortal/Content/themes/base/css?v=S-zQ78JrAzML_1efeX5_PcvcUJkva-SJIe1tYmUSk5U1" rel="stylesheet"/>
#
#     <link href="/Portal/WBBSuchePortal/Content/css?v=_kQl0Fdxc9dSIaF3TQkyDcTnonsDFiAiseHIxVt7hhU1" rel="stylesheet"/>
#
#     <link href="/Portal/WBBSuchePortal/Content/jPaginateCss?v=dbU3arAjAyrPzT4ETRwafCaD5uCxjNtCk0dThyVHttA1" rel="stylesheet"/>
#
#     <script src="/Portal/WBBSuchePortal/bundles/modernizr?v=K-FFpFNtIXPUlQamnX3qHX_A5r7TM2xbAgcuEmpm3O41"></script>
#
#     <script src="/Portal/WBBSuchePortal/bundles/jquery?v=yMmPM1TxecYcoWtCWW3jYgH0fr9kiAasOfb-W5I001A1"></script>
#
#     <script src="/Portal/WBBSuchePortal/bundles/jqueryui?v=y70dr8un4Tw2XdANU0qWa2Z_eettrMqLL_h29RBuTqA1"></script>
#
#     <script src="/Portal/WBBSuchePortal/bundles/jPaginate?v=sSmabrRTDp8GjbkO9C9dc3qmiatrEpGlFFA0sNWLcq41"></script>
#
#
#
#     <style>
#         .custom-combobox {
#             position: relative;
#             display: inline-block;
#             width: 100%;
#         }
#
#         .custom-combobox-input {
#             width: 90%;
#             margin: 0;
#         }
#
#         .custom-combobox-input#BefugnisInput,
#         .custom-combobox-input#BausteinInput {
#             width: 100%;
#             margin-right: -42px;
#             margin-top: 0.7px;
#         }
#
#         .custom-combobox-toggle {
#             position: absolute;
#             top: 0.7px;
#             bottom: 0px;
#             margin-left: -1px;
#             /* support: IE7 */
#             *height: 1.7em;
#             *top: 0.1em;
#         }
#
#         .ui-autocomplete {
#             max-height: 200px;
#             overflow-y: auto;   /* prevent horizontal scrollbar */
#             overflow-x: hidden; /* add padding to account for vertical scrollbar */
#             z-index:1000 !important;
#         }
#
#         .ui-button-display-on {
#             display: inline-block;
#         }
#
#         .ui-button-display-off {
#             display: none;
#         }
#     </style>
#     <script type="text/javascript">
#         (function ($) {
#             $.widget("custom.combobox", {
#                 _create: function () {
#                     this.wrapper = $("<span>")
#                       .addClass("custom-combobox")
#                       .insertAfter(this.element);
#
#                     this.element.hide();
#                     this._createAutocomplete();
#                     this._createShowAllButton();
#                 },
#
#                 _createAutocomplete: function () {
#                     var nameValue = this.element.attr("name");
#                     var tabindexValue = this.element.attr("tabindex");
#                     this.element.removeAttr("name");
#                     value = $("#" + nameValue + "Hidden").val();
#
#                     this.input = $("<input>")
#                       .appendTo(this.wrapper)
#                       .val(value)
#                       .attr({
#                           title: "",
#                           name: nameValue,
#                           tabindex: tabindexValue
#                       })
#                       .addClass("custom-combobox-input")
#                       .autocomplete({
#                           delay: 0,
#                           minLength: 0,
#                           source: $.proxy(this, "_source")
#                       })
#                       .tooltip({
#                           tooltipClass: "ui-state-highlight"
#                       });
#
#                     this.input.attr("id", this.input.attr("name") + "Input");
#
#                     this._on(this.input, {
#                         autocompleteselect: function (event, ui) {
#                             ui.item.option.selected = true;
#                             this._trigger("select", event, {
#                                 item: ui.item.option
#                             });
#                             if (event != null && event.target != null && event.target.id == "BefugnisInput") {
#                                 if (IsPsychoWbbFach(ui.item.option.text)) {
#                                     SetBausteinEnabled();
#                                 } else {
#                                     SetBausteinDisabled();
#                                 }
#                             }
#                         }
#                     });
#                 },
#
#                 _createShowAllButton: function () {
#                     var input = this.input,
#                       wasOpen = false;
#
#
#                     $("<a>")
#                       .attr("tabIndex", -1)
#                       .attr({
#                           title: ""
#                       })
#                       .attr("id", this.input.attr("name") + "ShowAllButton")
#                       .tooltip()
#                       .appendTo(this.wrapper)
#                       .button({
#                           icons: {
#                               primary: "ui-icon-triangle-1-s"
#                           },
#                           text: false
#                       })
#                       .removeClass("ui-corner-all")
#                       .addClass("custom-combobox-toggle")
#                       .mousedown(function () {
#                           wasOpen = input.autocomplete("widget").is(":visible");
#                       })
#                       .click(function () {
#                           input.focus();
#                           var nameValue = input.attr("name");
#                           $("#" + nameValue).trigger("focus");
#                           // Close if already visible
#                           if (wasOpen) {
#                               return;
#                           }
#
#                           // Pass empty string as value to search for, displaying all results
#                           input.autocomplete("search", "");
#                       });
#                 },
#
#                 _source: function (request, response) {
#                     var matcher = new RegExp($.ui.autocomplete.escapeRegex(request.term), "i");
#                     response(this.element.children("option").map(function () {
#                         var text = $(this).text();
#                         if (this.value && (!request.term || matcher.test(text)))
#                             return {
#                                 label: text,
#                                 value: text,
#                                 option: this
#                             };
#                     }));
#                 },
#
#                 _destroy: function () {
#                     this.wrapper.remove();
#                     this.element.show();
#                 }
#             });
#         })(jQuery);
#
#         $(function () {
#             $("#Befugnis").combobox();
#             $("#Baustein").combobox();
#
#             $("#paginator").paginate({
#                 count: '152',
#                 start: 1,
#                 display: 10,
#                 border: false,
#                 text_color: '#888',
#                 background_color: '#EEE',
#                 text_hover_color: 'black',
#                 background_hover_color: '#CFCFCF',
#                 images: false,
#                 mouse: 'press',
#                 rotate: false,
#                 onChange: function (page) {
#                     LoadSucheErgebnisPart(page);
#                 }
#             });
#         });
#
#         function LoadSucheErgebnisPart(paginationIndex) {
#             keepAliveSession();
#
#             $('#searchInput').val("true");
#             var additionalParams = { paginationIndex: paginationIndex };
#             var formData = $('#SucheForm').serialize() + "&" + $.param(additionalParams);
#             $.ajax({
#                 type: "POST",
#                 url: '/Portal/WBBSuchePortal/WBBSuchePortal/SucheEinfach',
#                 //dataType: 'json',
#                 data: formData,
#                 success: function (result) {
#                     $('#sucheErgebnisPart').html($(result).find('#sucheErgebnisPart'));
#                 },
#                 error: function (xhr, ajaxOptions, thrownError) {
#                     alert(xhr.status);
#                     alert(thrownError);
#
#                     alert("Fehler beim Laden");
#                 }
#             });
#         }
#
#         function IsPsychoWbbFach(fach) {
#             var isPsychoWbbFach = false;
#             if (fach != undefined && fach != null && fach.length > 0) {
#                 $.ajax({
#                     type: "POST",
#                     url: '/Portal/WBBSuchePortal/WBBSuchePortal/GetPsychoWbbBausteine',
#                     data: "{fach:'" + fach + "'}",
#                     contentType: "application/json; charset=utf-8",
#                     dataType: "json",
#                     async: false,
#                     success: function (msg) {
#                         if (msg.length > 0) {
#                             isPsychoWbbFach = true;
#                         }
#                     },
#                     error: function (xhr, ajaxOptions, thrownError) {
#                         alert(xhr.status);
#                         alert(thrownError);
#                         alert("Fehler beim Laden");
#                     }
#                 });
#             }
#             return isPsychoWbbFach;
#         }
#
#         function SetBausteinDisabled() {
#             $("#BausteinInput").val(null);
#             $("#BausteinInput").attr("disabled", true);
#             $("#BausteinShowAllButton").removeClass("ui-button-display-on");
#             $("#BausteinShowAllButton").addClass("ui-button-display-off");
#         }
#
#         function SetBausteinEnabled() {
#             $("#BausteinInput").attr("disabled", false);
#             $("#BausteinShowAllButton").removeClass("ui-button-display-off");
#             $("#BausteinShowAllButton").addClass("ui-button-display-on");
#         }
#
#         function suppressEmptyEntfernung() {
#             var entfernungElement = document.getElementById('Entfernung');
#             if (entfernungElement && entfernungElement != undefined && entfernungElement != null) {
#                 var entfernungValue = entfernungElement.value;
#                 if (!entfernungValue || entfernungValue == undefined || entfernungValue == null) {
#                     entfernungElement.value = "50";
#                 }
#             }
#         };
#     </script>
#
#
#     <script type="text/javascript">
#
#         //dim background and display loading circle, go to targetURL
#         function goToUrl(targetUrl, $parameters) {
#
#             keepAliveSession();
#
#             try {
#                 if ($("#loading-gif").length < 1) {
#                     $("body").append("<div id='dimmer'></div>");
#                     $("body").append("<div id='loading-gif'></div>");
#                     $("#dimmer").css({ "background-color": "black", "opacity": "0.75", "position": "absolute", "left": "0", "top": "0", "width": "100%", "z-index": "101", "height": $(document).height() });
#                     $("#loading-gif").css({ "background-image": "url(../Content/images/loading-circle.gif)", "background-position": "center center", "background-repeat": "no-repeat", "height": "50px", "width": "50px", "margin-top": "-25px", "margin-left": "-25px", "position": "fixed", "left": "50%", "top": "50%", "z-index": "102" });
#
#                     $(window).blur(function () {
#                         $("#dimmer").hide();
#                         $("#loading-gif").hide();
#                     });
#                 }
#
#                 $("#dimmer").show();
#                 $("#loading-gif").show();
#
#                 var parametersObject = { params: $parameters };
#                 setTimeout(function () {
#                     var new_form;
#                     new_form = $("<form id='form' method='get'></form>").attr("action", targetUrl);
#                     $("body").append(new_form);
#
#                     if (this.params != 'undefined') {
#                         var input;
#                         for (var paramName in this.params) {
#                             if (this.paramName != 'undefined') {
#                                 input = $("<input>")
#                                     .attr("type", "hidden")
#                                     .attr("name", paramName).val(this.params[paramName]);
#                                 $('#form').append($(input));
#                             }
#                         }
#                     }
#
#                     new_form.submit();
#
#                     $("#loading-gif").css("background-image", "url(../Content/images/loading-circle.gif" + "?random=" + new Date().getTime() + ")");
#                 }.bind(parametersObject), 100);
#             }
#             catch (err) {
#                 location.href = targetUrl;
#             }
#         }
#
#         function showTimer() {
#             if ($("#loading-gif").length < 1) {
#                 $("body").append("<div id='dimmer'></div>");
#                 $("body").append("<div id='loading-gif'></div>");
#                 $("#dimmer").css({ "background-color": "black", "opacity": "0.75", "position": "absolute", "left": "0", "top": "0", "width": "100%", "z-index": "101", "height": $(document).height() });
#                 $("#loading-gif").css({ "background-image": "url(../Content/images/loading-circle.gif)", "background-position": "center center", "background-repeat": "no-repeat", "height": "50px", "width": "50px", "margin-top": "-25px", "margin-left": "-25px", "position": "fixed", "left": "50%", "top": "50%", "z-index": "102" });
#
#                 $(window).blur(function () {
#                     $("#dimmer").hide();
#                     $("#loading-gif").hide();
#                 });
#             }
#
#             $("#dimmer").show();
#             $("#loading-gif").show();
#         }
#
#         function hideTimer() {
#             $("#loading-gif").css("background-image", "url(../Content/images/loading-circle.gif" + "?random=" + new Date().getTime() + ")");
#         }
#
#         function keepAliveSession() {
#         }
#     </script>
#
#         <!-- Einbettung in BLÄK-Homepage iframe -->
#         <script type="text/javascript" src="/_js/iframeResizer.contentWindow.min.js"></script>
#         <script type="text/javascript">
#             window.iFrameResizer = {
#                 onReady: function () {
#                     window.parentIFrame.scrollTo(0, 0)
#                 }
#             }
#         </script>
#
#         <link rel="stylesheet" href="/meineblaek/_assets/css/meineblaek-frame.css" />
#         <link rel="stylesheet" href="/meineblaek/_assets/css/scrolltop.css" media="all" type="text/css" />
#         <script type="text/javascript" src="/meineblaek/_assets/js/scrolltop.js"></script>
#
# </head>
#
#     <!-- CSS: frame-wrapper-full nur in Portal-Version -->
#
#     <body >
#
#
#     <br />
# <h2>Recherche von Weiterbildungsbefugnissen</h2>
# <p>
#     <div>
#         Hier können Sie nach in Bayern befugten Ärzten und Weiterbildungsstätten in Bayern suchen und Ihre Suchergebnisse als PDF abspeichern oder ausdrucken.
#     </div>
#     <div style="margin-top: 10px">
#         Bitte beachten Sie, dass in der Ergebnisliste pro Weiterbildungsbefugnis jeweils nur ein Weiterbilder und eine Weiterbildungsstätte angezeigt wird. Unter "Details" werden Ihnen alle Weiterbilder und alle Weiterbildungsstätten dieser Weiterbildungsbefugnis angezeigt.
#     </div>
#     <div style="margin-top: 10px">
#         Sollte das von Ihnen gesuchte Weiterbildungsfach oder der von Ihnen gesuchte Baustein nicht auswählbar sein, besteht derzeit keine aktuell gültige Weiterbildungsbefugnis oder kein aktuell gültiger Baustein.
#     </div>
# </p>
#
# <form action="/Portal/WBBSuchePortal/WBBSuchePortal/SucheEinfach" id="SucheForm" method="post">    <script src="https://maps.googleapis.com/maps/api/js?libraries=places&sensor=false&components=administrative_area:BY|country:DE&language=DE&key=AIzaSyCklsMQ90K1ZUpFw8Nuy0m_ZLYS3KXooWU"
#             type="text/javascript"></script>
#     <script type="text/javascript">
#         function SwitchSucheView() {
#             keepAliveSession();
#             window.location.href = '/Portal/WBBSuchePortal/WBBSuchePortal/Suche';
#         }
#
#         $(document).ready(function () {
#             // Baustein
#             $("#BausteinShowAllButton").unbind("click");
#             $("#BausteinShowAllButton").click(function () {
#                 GetBausteine($("#BefugnisInput").val());
#                 var input = $("#BausteinInput");
#                 input.focus();
#                 var nameValue = input.attr("name");
#                 $("#" + nameValue).trigger("focus");
#                 // Close if already visible
#                 if (input.autocomplete("widget").is(":visible")) {
#                     return;
#                 }
#
#                 // Pass empty string as value to search for, displaying all results
#                 input.autocomplete("search", "");
#             });
#             $("#BausteinInput").focus(
#                function (event, ui) {
#                    GetBausteine($("#BefugnisInput").val());
#                }
#             );
#             var bausteinValue = $("#BausteinInput").val();
#             var bausteinValueExists = (bausteinValue != undefined && bausteinValue != null && bausteinValue.length > 0);
#             if (bausteinValueExists || IsPsychoWbbFach($("#BefugnisInput").val())) {
#                 SetBausteinEnabled();
#             } else {
#                 SetBausteinDisabled();
#             }
#             // initial focus
#             $("#BefugnisInput").focus();
#         });
#
#         function GetBausteine(fach) {
#             $("#Baustein").get(0).options.length = 0;
#             $("#Baustein").get(0).options[0] = new Option("Bausteine laden...", "-1");
#
#             $.ajax({
#                 type: "POST",
#                 url: '/Portal/WBBSuchePortal/WBBSuchePortal/GetPsychoWbbBausteine',
#                 data: "{fach:'" + fach + "'}",
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 async: false,
#                 success: function (msg) {
#                     $("#Baustein").get(0).options.length = 0;
#                     if (msg.length == 0) {
#                         $("#Baustein").get(0).options[0] = new Option("Keine Bausteine vorhanden.", "-1");
#                     } else {
#                         $.each(msg, function (index, item) {
#                             $("#Baustein").get(0).options[$("#Baustein").get(0).options.length] = new Option(item, index);
#                         });
#                     }
#                 },
#                 error: function (xhr, ajaxOptions, thrownError) {
#                     alert(xhr.status);
#                     alert(thrownError);
#
#                     $("#Baustein").get(0).options.length = 0;
#                     alert("Fehler beim Laden");
#                 }
#             });
#         };
#     </script>
#     <script type="text/javascript">
#         function initialize() {
#
#             var options = {
#                 componentRestrictions: { country: "de" }
#             };
#
#             var input = (document.getElementById('wohnort'));
#             var autocomplete = new window.google.maps.places.Autocomplete(input, options);
#             var infowindow = new window.google.maps.InfoWindow();
#
#             window.google.maps.event.addListener(autocomplete, 'place_changed', function () {
#                 infowindow.close();
#
#                 var place = autocomplete.getPlace();
#                 if (!place.geometry) {
#                     return;
#                 }
#
#                 var address = '';
#                 if (place.address_components) {
#                     address = [
#                       (place.address_components[0] && place.address_components[0].short_name || ''),
#                       (place.address_components[1] && place.address_components[1].short_name || ''),
#                       (place.address_components[2] && place.address_components[2].short_name || '')
#                     ].join(' ');
#                 }
#
#                 infowindow.setContent('<div><strong>' + place.name + '</strong><br>' + address);
#             });
#         }
#
#         google.maps.event.addDomListener(window, 'load', initialize);
#     </script>
#     <table style="border: 1px solid #CCCCCC; padding: 14px">
#         <colgroup>
#             <col style="width: 10px">
#             <col style="width: 100%">
#         </colgroup>
#         <tr>
#             <td>
#             </td>
#             <td>
#                 <span style="white-space: nowrap; margin-right: 50px;">
#                     <input checked="checked" id="SuchArt" name="SuchArt" tabindex="1" type="radio" value="einfach" /> einfache Suche
#                 </span>
#                 <span style="white-space: nowrap;">
#                     <input id="SuchArt" name="SuchArt" onclick="SwitchSucheView();" tabindex="1" type="radio" value="erweitert" /> erweiterte Suche
#                 </span>
#             </td>
#         </tr>
#         <tr>
#             <td colspan="2" style="text-decoration: underline">
#                 Kriterien zur Befugnis:
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Weiterbildungsfach
#             </td>
#             <td style="min-width: 100px; ">
#                 <div style="width: 90%">
#                     <select id="Befugnis" name="Befugnis" tabindex="2"><option selected="selected" value=""></option>
# <option value="100 Stunden Fallseminare für die Zusatz-Weiterbildung Homöopathie">100 Stunden Fallseminare f&#252;r die Zusatz-Weiterbildung Hom&#246;opathie</option>
# <option value="120 Stunden Fallseminare für die Zusatz-Weiterbildung Ernährungsmedizin">120 Stunden Fallseminare f&#252;r die Zusatz-Weiterbildung Ern&#228;hrungsmedizin</option>
# <option value="120 Stunden Fallseminare für die Zusatz-Weiterbildung Palliativmedizin">120 Stunden Fallseminare f&#252;r die Zusatz-Weiterbildung Palliativmedizin</option>
# <option value="20 Stunden Fallseminare für die Zusatz-Weiterbildung Akupunktur">20 Stunden Fallseminare f&#252;r die Zusatz-Weiterbildung Akupunktur</option>
# <option value="80 Stunden Fallseminare für die Zusatz-Weiterbildung Naturheilverfahren">80 Stunden Fallseminare f&#252;r die Zusatz-Weiterbildung Naturheilverfahren</option>
# <option value="FA Allgemeinchirurgie">FA Allgemeinchirurgie</option>
# <option value="FA Allgemeinmedizin (ambulante hausärztliche Versorgung)">FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung)</option>
# <option value="FA Anästhesiologie">FA An&#228;sthesiologie</option>
# <option value="FA Anatomie">FA Anatomie</option>
# <option value="FA Arbeitsmedizin">FA Arbeitsmedizin</option>
# <option value="FA Augenheilkunde">FA Augenheilkunde</option>
# <option value="FA Frauenheilkunde und Geburtshilfe">FA Frauenheilkunde und Geburtshilfe</option>
# <option value="FA Gefäßchirurgie">FA Gef&#228;&#223;chirurgie</option>
# <option value="FA Hals-Nasen-Ohrenheilkunde">FA Hals-Nasen-Ohrenheilkunde</option>
# <option value="FA Haut- und Geschlechtskrankheiten">FA Haut- und Geschlechtskrankheiten</option>
# <option value="FA Herzchirurgie">FA Herzchirurgie</option>
# <option value="FA Humangenetik">FA Humangenetik</option>
# <option value="FA Hygiene und Umweltmedizin">FA Hygiene und Umweltmedizin</option>
# <option value="ZB Psychoanalyse (PA)">ZB Psychoanalyse (PA)</option>
# <option value="ZB Psychotherapie (allgemein)">ZB Psychotherapie (allgemein)</option>
# <option value="ZB Psychotherapie (PT)">ZB Psychotherapie (PT)</option>
# <option value="ZB Psychotherapie (VT)">ZB Psychotherapie (VT)</option>
# <option value="ZB Rehabilitationswesen">ZB Rehabilitationswesen</option>
# <option value="ZB Röntgendiagnostik - Gefäßsystem">ZB R&#246;ntgendiagnostik - Gef&#228;&#223;system</option>
# <option value="ZB Röntgendiagnostik - Harntrakt">ZB R&#246;ntgendiagnostik - Harntrakt</option>
# <option value="ZB Röntgendiagnostik - Mamma">ZB R&#246;ntgendiagnostik - Mamma</option>
# <option value="ZB Röntgendiagnostik - Skelett">ZB R&#246;ntgendiagnostik - Skelett</option>
# <option value="ZB Röntgendiagnostik - Thorax">ZB R&#246;ntgendiagnostik - Thorax</option>
# <option value="ZB Schlafmedizin">ZB Schlafmedizin</option>
# <option value="ZB Sozialmedizin">ZB Sozialmedizin</option>
# <option value="ZB Spezielle Orthopädische Chirurgie">ZB Spezielle Orthop&#228;dische Chirurgie</option>
# <option value="ZB Spezielle Schmerztherapie">ZB Spezielle Schmerztherapie</option>
# <option value="ZB Spezielle Unfallchirurgie">ZB Spezielle Unfallchirurgie</option>
# <option value="ZB Spezielle Viszeralchirurgie">ZB Spezielle Viszeralchirurgie</option>
# <option value="ZB Sportmedizin">ZB Sportmedizin</option>
# <option value="ZB Tropenmedizin">ZB Tropenmedizin</option>
# </select>
#                     <input id="BefugnisHidden" type="hidden" value="" />
#                 </div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Baustein
#             </td>
#             <td style="min-width: 100px; ">
#                 <div style="width: 90%">
#                     <select id="Baustein" name="Baustein" tabindex="3"><option selected="selected" value=""></option>
# <option value="Autogenes Training">Autogenes Training</option>
# <option value="Balintgruppe">Balintgruppe</option>
# <option value="Bioenergetik">Bioenergetik</option>
# <option value="Einzelanalyse">Einzelanalyse</option>
# <option value="Einzelselbsterfahrung">Einzelselbsterfahrung</option>
# <option value="Familientherapie">Familientherapie</option>
# <option value="Funktionelle Entspannungstherapie">Funktionelle Entspannungstherapie</option>
# <option value="Gesprächstherapie nach Rogers">Gespr&#228;chstherapie nach Rogers</option>
# <option value="Gestalttherapie">Gestalttherapie</option>
# <option value="Gruppenpsychoanalyse">Gruppenpsychoanalyse</option>
# <option value="Gruppenpsychotherapie">Gruppenpsychotherapie</option>
# <option value="Hypnose">Hypnose</option>
# <option value="IFA-Gruppe">IFA-Gruppe</option>
# <option value="Katathym-imaginative Psychotherapie (K.I.P.)">Katathym-imaginative Psychotherapie (K.I.P.)</option>
# <option value="Konzentrative Bewegungstherapie">Konzentrative Bewegungstherapie</option>
# <option value="Progressive Muskelrelaxation nach Jacobsen">Progressive Muskelrelaxation nach Jacobsen</option>
# <option value="Psychodrama">Psychodrama</option>
# <option value="Selbsterfahrungsgruppe">Selbsterfahrungsgruppe</option>
# <option value="Supervision der Gruppenpsychoanalyse">Supervision der Gruppenpsychoanalyse</option>
# <option value="Supervision der Gruppenpsychotherapie">Supervision der Gruppenpsychotherapie</option>
# <option value="Supervision der Kindergruppenpsychoanalyse">Supervision der Kindergruppenpsychoanalyse</option>
# <option value="Supervision der Kindergruppenpsychotherapie">Supervision der Kindergruppenpsychotherapie</option>
# <option value="Supervision einzeln von Erwachsenen">Supervision einzeln von Erwachsenen</option>
# <option value="Supervision einzeln von Kindern und Jugendlichen">Supervision einzeln von Kindern und Jugendlichen</option>
# <option value="Supervision einzeln von Kindern, Jugendlichen und Erwachsenen">Supervision einzeln von Kindern, Jugendlichen und Erwachsenen</option>
# <option value="Supervision einzeln/Gruppe von Erwachsenen">Supervision einzeln/Gruppe von Erwachsenen</option>
# <option value="Supervision einzeln/Gruppe von Kindern und Jugendlichen">Supervision einzeln/Gruppe von Kindern und Jugendlichen</option>
# <option value="Supervision einzeln/Gruppe von Kindern, Jugendlichen und Erwachsenen">Supervision einzeln/Gruppe von Kindern, Jugendlichen und Erwachsenen</option>
# <option value="Supervision in der Gruppe von Erwachsenen">Supervision in der Gruppe von Erwachsenen</option>
# <option value="Supervision in der Gruppe von Kindern und Jugendlichen">Supervision in der Gruppe von Kindern und Jugendlichen</option>
# <option value="Supervision in der Gruppe von Kindern, Jugendlichen und Erwachsenen">Supervision in der Gruppe von Kindern, Jugendlichen und Erwachsenen</option>
# <option value="Systemische Familientherapie">Systemische Familientherapie</option>
# <option value="Systemische Therapie">Systemische Therapie</option>
# <option value="Theorie">Theorie</option>
# <option value="Transaktionsanalyse">Transaktionsanalyse</option>
# <option value="Weiteres Verfahren">Weiteres Verfahren</option>
# </select>
#                     <input id="BausteinHidden" type="hidden" />
#                 </div>
#             </td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>
#                 Weiterbildungsbefugter
#             </td>
#             <td style="min-width: 100px; ">
#                 <input id="Arzt" maxlength="90" name="Arzt" style="width: 90%;" tabindex="4" type="text" value="" />
#             </td>
#         </tr>
#         <tr>
#             <td colspan="2" style="padding-top: 10px; text-decoration: underline">
#                 Umkreissuche:
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Standort
#             </td>
#             <td>
#                 <table style="width:90%; border: 0px;" cellpadding="0" cellspacing="0">
#                     <tr>
#                         <td style="min-width: 70px;">
#                             <input id="wohnort" maxlength="200" name="wohnort" placeholder="" style="width: 100%;" tabindex="5" type="text" value="" />
#                         </td>
#                         <td style="width: 50px; padding-left: 40px; padding-right: 10px">
#                             Umkreis
#                         </td>
#                         <td style="min-width: 30px; white-space: nowrap;">
#                             <input id="Entfernung" maxlength="5" name="Entfernung" onchange="suppressEmptyEntfernung();" style="width: 40px;" tabindex="6" type="text" value="50" /> km
#                         </td>
#                     </tr>
#                 </table>
#             </td>
#         </tr>
#         <tr>
#             <td style="padding-top: 15px;"></td>
#             <td style="padding-top: 15px;">
#                 <input id="searchInput" type="hidden" name="search">
#                 <input type="submit" tabindex="7" value="Suchen" onclick="keepAliveSession(); this.form.search.value = true;" style="margin-right: 50px;" />
#                 <span style="white-space: nowrap;">
#                     Suchergebnisse pro Seite
#                     <select id="Anzahl" name="Anzahl" style="height: 21px;" tabindex="8"><option value="10">10</option>
# <option value="25">25</option>
# <option value="50">50</option>
# <option selected="selected" value="100">100</option>
# </select>
#                 </span>
#             </td>
#         </tr>
#     </table>
#     <p></p>
#         <div id="paginator"></div>
# </form><p>
# </p>
#
# <div style="background: url(/Portal/WBBSuchePortal/WBBSuchePortal/GetWasserzeichen); background-repeat:repeat-y;background-position:120px 100px;">
#     <div id="sucheErgebnisPart">
#                 <table style="width: 100%" border="0" cellspacing="0" cellpadding="0">
#                     <tr>
#                         <td style="vertical-align: top;">
#                             15101 - 15132 von 15132 gefundenen Ergebnissen.
#                         </td>
#                         <td style="vertical-align: top; text-align: right;">
#                             Angezeigte Ergebnisse als PDF herunterladen:
#                         </td>
#                         <td>
#                             <a href="/Portal/WBBSuchePortal/WBBSuchePortal/SucheEinfachDrucken?paginationIndex=152" onclick="keepAliveSession();" target="_blank"><img alt="" src="/Portal/WBBSuchePortal/Content/images/pdf.jpg" style="vertical-align:text-bottom;border: 0px;" /></a>
#                         </td>
#                     </tr>
#                 </table>
#
#
#
# <div>
#     <table style="width:100%; padding-right: 14px;" border="0" cellspacing="0" cellpadding="5">
#             <colgroup>
#                 <col style="width:50%">
#                 <col style="width:40%">
#                 <col style="width:10%">
#             </colgroup>
#                     <tr>
#                 <th style="padding-bottom: 5px; text-align: left; ">
#                     Weiterbildungsstätten
#                 </th>
#                 <th style="padding-bottom: 5px; text-align: left; ">
#                     Befugnisse
#                 </th>
#                 <th style="padding-bottom: 5px; ">
#                 </th>
#             </tr>
#
#             <tr style="background-color: rgba(238, 238, 238, 0.4); ">
#                 <td style="vertical-align: top; ">
# Gemeinschaftspraxis Dr. Volkening und Herr Weierich<br />
# 97816 Lohr<br />
# Sendelbacher Str. 14                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 17. Oktober 2010<br />
# B39706<span>, </span>
# 24<span> </span>
# Monate
#                     <br />
#                         <span>mit Nebenbestimmung(en)</span>
#                         <br />
#                     Dr. med.                                <span> </span>
# Gabriele                                <span> </span>
# Volkening                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B39706" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Bosch Rexroth AG<br />
# Werks&#228;rztlicher Dienst<br />
# 97816 Lohr<br />
# Zum Eisengie&#223;er 1                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Arbeitsmedizin, Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24.04.2004<br />
# B36842<span>, </span>
# 36<span> </span>
# Monate
#                     <br />
#                     Dr. med.                                <span> </span>
# Benedikt                                <span> </span>
# Born                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B36842" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(238, 238, 238, 0.4); ">
#                 <td style="vertical-align: top; ">
# Klinikum Main-Spessart Marktheidenfeld<br />
# Abteilung f&#252;r Geriatrie und Innere Medizin<br />
# 97828 Marktheidenfeld<br />
# Baumhofstr. 91 - 93                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Innere Medizin, Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 28. Oktober 2018<br />
# B48688<span>, </span>
# 24<span> </span>
# Monate
#                     <br />
#                         <span>mit Nebenbestimmung(en)</span>
#                         <br />
#                     Dr. med.                                <span> </span>
# Walter                                <span> </span>
# Swoboda                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B48688" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Klinikum Main-Spessart Marktheidenfeld<br />
# Abteilung f&#252;r Geriatrie und Innere Medizin<br />
# 97828 Marktheidenfeld<br />
# Baumhofstr. 91 - 93                </td>
#                 <td style="vertical-align: top; ">
#
#                     WB Innere Medizin (Basisweiterbildung)<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 17. Oktober 2010<br />
#
</td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 28. Oktober 2018<br />
# B54621<span>, </span>
# 24<span> </span>
# Monate
#                     <br />
#                         <span>mit Nebenbestimmung(en)</span>
#                         <br />
#                     Dr. med.                                <span> </span>
# Michael                                <span> </span>
# Brack                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B54621" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Betriebsmedizin Wertheim Dr. Schmid<br />
# 97892 Kreuzwertheim<br />
# Im Laufer 28                </td>
#                 <td style="vertical-align: top; ">
#
#                     ZB Betriebsmedizin, Zusatz-Weiterbildung<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24.04.2004<br />
# B44784<span>, </span>
# 9<span> </span>
# Monate
#                     <br />
#                     Dr. med.                                <span> </span>
# Axel                                <span> </span>
# Schmid                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B44784" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(238, 238, 238, 0.4); ">
#                 <td style="vertical-align: top; ">
# Praxis am Kaffelstein <br />
# 97892 Kreuzwertheim<br />
# Lengfurter Str. 53                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 17. Oktober 2010<br />
# B56003<span>, </span>
# 18<span> </span>
# Monate
#                     <br />
#                     Dr. med. univ.                                <span> </span>
# Stefan                                <span> </span>
# Brunner                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B56003" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Praxis am Kaffelstein <br />
# 97892 Kreuzwertheim<br />
# Lengfurter Str. 53                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 28. Oktober 2018<br />
# B55262<span>, </span>
# 18<span> </span>
# Monate
#                     <br />
#                     Dr. med. univ.                                <span> </span>
# Stefan                                <span> </span>
# Brunner                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B55262" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(238, 238, 238, 0.4); ">
#                 <td style="vertical-align: top; ">
# Praxis am Kaffelstein <br />
# 97892 Kreuzwertheim<br />
# Lengfurter Str. 53                </td>
#                 <td style="vertical-align: top; ">
#
#                     ZB Betriebsmedizin, Zusatz-Weiterbildung<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24.04.2004<br />
# B43684<span>, </span>
# 9<span> </span>
# Monate
#                     <br />
#                     Dr. med.                                <span> </span>
# Julius                                <span> </span>
# Brunner                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B43684" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Praxis Herr Klemm<br />
# 97901 Altenbuch<br />
# Steinbrunnstr. 18                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 17. Oktober 2010<br />
# B46933<span>, </span>
# 12<span> </span>
# Monate
#                     <br />
#                     Gunther                                <span> </span>
# Klemm                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B46933" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(238, 238, 238, 0.4); ">
#                 <td style="vertical-align: top; ">
# Allgemeinarztpraxis Neff<br />
# 97909 Stadtprozelten<br />
# Hauptstr. 66                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 17. Oktober 2010<br />
# B56305<span>, </span>
# 18<span> </span>
# Monate
#                     <br />
#                     Peter                                <span> </span>
# Neff                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B56305" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#             <tr style="background-color: rgba(255, 255, 255, 0.4); ">
#                 <td style="vertical-align: top; ">
# Allgemeinarztpraxis Neff<br />
# 97909 Stadtprozelten<br />
# Hauptstr. 66                </td>
#                 <td style="vertical-align: top; ">
#
#                     FA Allgemeinmedizin (ambulante haus&#228;rztliche Versorgung), Facharzt<br />
#
#
# Weiterbildungsordnung f&#252;r die &#196;rzte Bayerns vom 24. April 2004 in der Fassung der Beschl&#252;sse vom 28. Oktober 2018<br />
# B56306<span>, </span>
# 18<span> </span>
# Monate
#                     <br />
#                     Peter                                <span> </span>
# Neff                            <br />
#
#                 </td>
#                 <td style="text-align: right; ">
# <a href="/Portal/WBBSuchePortal/WBBSuchePortal/Details?befugnisNummer=B56306" onclick="keepAliveSession();">Details...</a>                </td>
#             </tr>
#     </table>
# </div>
# <br />
#
#     </div>
# </div>
# <p>
#     Sollte sich das von Ihnen gewünschte / erwartete Suchergebnis nicht einstellen, kontaktieren Sie bitte unser Informationszentrum unter 089 4147-138.
# </p>
#
#
#         <a id="back-to-top" href="#" class="btn-lg back-to-top" role="button" title="Zum Anfang der Seite springen" data-toggle="tooltip" data-placement="left">
#             <span class="icon_scroll" />
#         </a>
#     </body>
# </html>

# %%
from bs4 import BeautifulSoup


soup =  BeautifulSoup(response.text,'html.parser')
